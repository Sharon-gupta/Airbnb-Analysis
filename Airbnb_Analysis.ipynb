# %%
import pandas as pd

# %%
airbnb = pd.read_csv("sample_airbnb.listingsAndReviews.csv")
# Out:
# <ipython-input-17-4cc214446487>:1: DtypeWarning: Columns (0,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,122,123,124,136,137,138,148,859,860,861,862,863,864,865,866,867,868,869,870,871,872,873,874,875,876,877,878,879,880,881,882,883,884,885,886,887,888,889,890,891,892,893,894,895,896,897,898,899,900,901,902,903,904,905,906,907,908,909,910,911,912,913,914,915,916,917,918,919,920,921,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,957,958,959,960,961,962,963,964,965,966,967,968,969,970,971,972,973,974,975,976,977,978,979,980,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1019,1020,1021,1022,1023,1024,1025,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1036,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,105
# ...

# %%
airbnb.shape
# Out:
# (5557, 3361)

# %%
airbnb.head()
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
# 2   1001265   https://www.airbnb.com/rooms/1001265
# 3  10021707  https://www.airbnb.com/rooms/10021707
# 4  10030955  https://www.airbnb.com/rooms/10030955
#
#                                name  \
# 0           Ribeira Charming Duplex
# 1      Horto flat with small garden
# 2  Ocean View Waikiki Marina w/prkg
# 3          Private Room in Bushwick
# 4       Apt Linda Vista Lagoa - Rio
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
# 2  A short distance from Honolulu's billion dolla...
# 3  Here exists a very cozy room for rent in a sha...
# 4  Quarto com vista para a Lagoa Rodrigo de Freit...
#
#                                                space  \
# ...

# %%
airbnb.tail()
# Out:
#                            _id                            listing_url  \
# 5552                   9987200   https://www.airbnb.com/rooms/9987200
# 5553                   9990304   https://www.airbnb.com/rooms/9990304
# 5554                   9993190   https://www.airbnb.com/rooms/9993190
# 5555  64e636d796106be00d03fb46                                    NaN
# 5556  64e63ae32b568f52b3fe22d0  https://www.airbnb.com/rooms/10006546
#
#                                                    name  \
# 5552       The best suite in Copacabana (total privacy)
# 5553     March Madness Special! Aina Nalu Platinum D107
# 5554  Just Steps from the Ocean at Premier Platinum ...
# 5555                                                NaN
# 5556                            Ribeira Charming Duplex
#
#                                                 summary  \
# 5552  Excellent private suite with bathroom at the A...
# 5553  Walk out to Saltwater Infinity Pool! Call us N...
# ...

# %%
airbnb.columns
# Out:
# Index(['_id', 'listing_url', 'name', 'summary', 'space', 'description',
#        'neighborhood_overview', 'notes', 'transit', 'access',
#        ...
#        'reviews[526].comments', 'reviews[527].comments',
#        'reviews[528].comments', 'reviews[529].comments',
#        'reviews[530].comments', 'reviews[531].comments',
#        'reviews[532].comments', 'weekly_price', 'monthly_price',
#        'reviews_per_month'],
#       dtype='object', length=3361)

# %%
airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5557 entries, 0 to 5556
# Columns: 3361 entries, _id to reviews_per_month
# dtypes: float64(1634), object(1727)
# memory usage: 142.5+ MB

# %%
airbnb.describe()
# Out:
#        minimum_nights  maximum_nights  accommodates     bedrooms         beds  \
# count     5556.000000    5.556000e+03   5556.000000  5551.000000  5543.000000
# mean         5.563715    1.382527e+06      3.506659     1.411998     2.071983
# std         22.611876    5.256447e+07      2.297604     1.042067     1.619992
# min          1.000000    1.000000e+00      1.000000     0.000000     0.000000
# 25%          1.000000    5.825000e+01      2.000000     1.000000     1.000000
# 50%          2.000000    1.125000e+03      3.000000     1.000000     2.000000
# 75%          3.000000    1.125000e+03      4.000000     2.000000     3.000000
# max       1250.000000    2.147484e+09     16.000000    20.000000    25.000000
#
#        number_of_reviews    bathrooms         price  security_deposit  \
# count        5556.000000  5546.000000   5556.000000       3472.000000
# mean           27.610691     1.291111    278.730382        509.341302
# ...

# %%
 airbnb.dropna(axis=1,how='all')
# Out:
#                            _id                            listing_url  \
# 0                     10006546  https://www.airbnb.com/rooms/10006546
# 1                     10009999  https://www.airbnb.com/rooms/10009999
# 2                      1001265   https://www.airbnb.com/rooms/1001265
# 3                     10021707  https://www.airbnb.com/rooms/10021707
# 4                     10030955  https://www.airbnb.com/rooms/10030955
# ...                        ...                                    ...
# 5552                   9987200   https://www.airbnb.com/rooms/9987200
# 5553                   9990304   https://www.airbnb.com/rooms/9990304
# 5554                   9993190   https://www.airbnb.com/rooms/9993190
# 5555  64e636d796106be00d03fb46                                    NaN
# 5556  64e63ae32b568f52b3fe22d0  https://www.airbnb.com/rooms/10006546
#
#                                                    name  \
# 0                               Ribeira Charming Duplex
# ...
